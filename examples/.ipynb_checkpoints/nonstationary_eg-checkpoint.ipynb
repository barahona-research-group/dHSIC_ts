# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append('/Users/Tim/PycharmProjects/HOI/')

# %%
import sys
sys.path
# Out:
# ['/Users/tim/PycharmProjects/HOI/examples',
#  '/Users/tim/opt/anaconda3/lib/python39.zip',
#  '/Users/tim/opt/anaconda3/lib/python3.9',
#  '/Users/tim/opt/anaconda3/lib/python3.9/lib-dynload',
#  '',
#  '/Users/tim/opt/anaconda3/lib/python3.9/site-packages',
#  '/Users/tim/opt/anaconda3/lib/python3.9/site-packages/aeosa',
#  '/Users/Tim/PycharmProjects/HOI/']

# %%
import os
os.getcwd()
# Out:
# '/Users/tim/PycharmProjects/HOI/examples'

# %%
import numba
import pandas as pd
import numpy as np
from tqdm.notebook import tqdm
from ipywidgets import IntProgress

# %%
from synthetic_data import stationary_pb_ts, nonstationary_ts_n, stationary_pb_ts_n
from HOI.preprocessings import compute_kernel, compute_kernel_n
from HOI.tests import test_independence

# %%
import matplotlib.pyplot as plt

def plot_test(data, mode):
    x = np.arange(0.1, 1, 0.1)
    y = np.array(data)

    fig = plt.figure(dpi=800)
    ax = fig.add_subplot(111)
    ax.set_ylim(0,1.05)
    ax.set_xlabel('dependence coefficient')
    ax.set_ylabel(mode)
    ax.set_title(mode + ' of dHSIC independence tests')
    plt.plot(x,y, marker='o', color='b')
    for i,j in zip(x,y):
        ax.annotate(str(j),xy=(i,j))
    plt.show()

# %% [markdown]
# # triangle

# %% [markdown]
# ## case2, z = x+y, gt_rejects = [1, 0, 1, 1]

# %%
power ={}
for d in tqdm(np.arange(0.1, 1, 0.1)):
    rejects = 0
    for i in tqdm(np.arange(100)):
        d1, d2, _, d3 = nonstationary_ts_n(n_sample=300, t_time=10, d=d, mode='case2', a=0.5, order=3)
        kd1 = compute_kernel_n(d1)
        kd2 = compute_kernel_n(d2)
        kd3 = compute_kernel_n(d3)
        _, _, _, reject = test_independence([kd1, kd2, kd3],None, mode = 'iid', n_perms=5000, alpha=0.05)
        rejects = rejects + reject + reject_1*2
    power[str(d)] = rejects/100
    print(power)
print(power)
# Out:
#   0%|          | 0/9 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# {'0.1': 0.92}
#   0%|          | 0/100 [00:00<?, ?it/s]
# {'0.1': 0.92, '0.2': 1.0}
#   0%|          | 0/100 [00:00<?, ?it/s]
# {'0.1': 0.92, '0.2': 1.0, '0.30000000000000004': 1.0}
#   0%|          | 0/100 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [12], in <cell line: 2>()
#       7     kd2 = compute_kernel_n(d2)
#       8     kd3 = compute_kernel_n(d3)
# ----> 9     _, _, _, reject = test_independence([kd1, kd2, kd3],None, mode = 'iid', n_perms=5000, alpha=0.05)
#      10     rejects = rejects + reject + reject_1*2
#      11 power[str(d)] = rejects/100
#
# File /Users/Tim/PycharmProjects/HOI/HOI/tests.py:170, in test_independence(k_list, data_list, mode, n_perms, alpha)
#     168 if mode == 'iid':
#     169     statistic = compute_dHSIC_statistics(k_list)
# --> 170     critical_value, pval = permutation(k_list, n_samples, n_variables, statistic, n_perms, alpha)
#     171     reject = int(statistic > critical_value)
#     172     return statistic, critical_value, pval, reject
#
# File /Users/Tim/PycharmProjects/HOI/HOI/tests.py:31, in permutation(k_list, n_samples, n_variables, stat_found, n_perms, alpha)
#      29 for j in range(1, n_variables):
#      30     index_perm = np.random.permutation(k_list[j].shape[0])
# ---> 31     k_perm = k_list[j][index_perm, index_perm[:, None]]
#      33     term1 = term1 * k_perm
#      34     term2 = term2 * np.sum(k_perm) / (n_samples ** 2)
#
# KeyboardInterrupt:

# %%
power_new = {'0.1': 0.92, 
             '0.2': 1, 
             '0.3': 1, 
             '0.4': 1,
             '0.5': 1, 
             '0.6': 1,
             '0.7': 1, 
             '0.8': 1,
             '0.9': 1}

# %%
plot_test(list(power_new.values()), 'power')

# %%
power ={}
for d in tqdm(np.arange(0.2, 1, 0.1)):
    rejects = 0
    for i in tqdm(np.arange(100)):
        d1, d2, _, d3 = nonstationary_ts_n(n_sample=300, t_time=10, d=d, mode='case2', a=0.5, order=3)
        kd1 = compute_kernel_n(d1)
        kd3 = compute_kernel_n(d3)
        _, _, _, reject = test_independence([kd1, kd3],None, mode = 'iid', n_perms=5000, alpha=0.05)
        rejects = rejects + reject
    power[str(d)] = rejects/100
    print(power)
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# {'0.2': 1.0}
#   0%|          | 0/100 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [11], in <cell line: 2>()
#       6     kd1 = compute_kernel_n(d1)
#       7     kd3 = compute_kernel_n(d3)
# ----> 8     _, _, _, reject = test_independence([kd1, kd3],None, mode = 'iid', n_perms=5000, alpha=0.05)
#       9     rejects = rejects + reject
#      10 power[str(d)] = rejects/100
#
# File /Users/Tim/PycharmProjects/HOI/HOI/tests.py:200, in test_independence(k_list, data_list, mode, n_perms, alpha)
#     198 if mode == 'iid':
#     199     statistic = compute_dHSIC_statistics(k_list)
# --> 200     critical_value, pval = dhsic_permutation(k_list, n_samples, n_variables, statistic, n_perms, alpha)
#     201     reject = int(statistic > critical_value)
#     202     return statistic, critical_value, pval, reject
#
# File /Users/Tim/PycharmProjects/HOI/HOI/tests.py:26, in dhsic_permutation(k_list, n_samples, n_variables, stat_found, n_perms, alpha)
#      24 for i in range(n_perms):
#      25     term1 = k_list[0]
# ---> 26     term2 = np.sum(k_list[0]) / (n_samples ** 2)
#      27     term3 = 2 * np.sum(k_list[0], axis=0) / (n_samples ** 2)
#      29     for j in range(1, n_variables):
#
# File <__array_function__ internals>:5, in sum(*args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/numpy/core/fromnumeric.py:2259, in sum(a, axis, dtype, out, keepdims, initial, where)
#    2256         return out
#    2257     return res
# -> 2259 return _wrapreduction(a, np.add, 'sum', axis, dtype, out, keepdims=keepdims,
#    2260                       initial=initial, where=where)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/numpy/core/fromnumeric.py:86, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      83         else:
#      84             return reduction(axis=axis, out=out, **passkwargs)
# ---> 86 return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# KeyboardInterrupt:

# %% [markdown]
# # case1, z = xy, gt_rejects = [1, 0, 0, 0]

# %%
power ={}
for d in tqdm(np.arange(0.1, 1, 0.1)):
    rejects = 0
    for i in tqdm(np.arange(100)):
        d1, d2, _, d3 = nonstationary_ts_n(n_sample=300, t_time=10, d=d, mode='case1', a=0.5, order=3)
        kd1 = compute_kernel_n(d1)
        kd2 = compute_kernel_n(d2)
        kd3 = compute_kernel_n(d3)
        _, _, _, reject = test_independence([kd1, kd2, kd3],None,
                                                  mode = 'iid', n_perms=5000, alpha=0.05)
        
        rejects = rejects + reject
    power[str(d)] = rejects/100
    print(power)
print(power)
# Out:
#   0%|          | 0/9 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# {'0.1': 1.0}
#   0%|          | 0/100 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [13], in <cell line: 2>()
#       7     kd2 = compute_kernel_n(d2)
#       8     kd3 = compute_kernel_n(d3)
# ----> 9     _, _, _, reject = test_independence([kd1, kd2, kd3],None,
#      10                                               mode = 'iid', n_perms=5000, alpha=0.05)
#      12     rejects = rejects + reject
#      13 power[str(d)] = rejects/100
#
# File /Users/Tim/PycharmProjects/HOI/HOI/tests.py:170, in test_independence(k_list, data_list, mode, n_perms, alpha)
#     168 if mode == 'iid':
#     169     statistic = compute_dHSIC_statistics(k_list)
# --> 170     critical_value, pval = permutation(k_list, n_samples, n_variables, statistic, n_perms, alpha)
#     171     reject = int(statistic > critical_value)
#     172     return statistic, critical_value, pval, reject
#
# File /Users/Tim/PycharmProjects/HOI/HOI/tests.py:34, in permutation(k_list, n_samples, n_variables, stat_found, n_perms, alpha)
#      31     k_perm = k_list[j][index_perm, index_perm[:, None]]
#      33     term1 = term1 * k_perm
# ---> 34     term2 = term2 * np.sum(k_perm) / (n_samples ** 2)
#      35     term3 = term3 * np.sum(k_perm, axis=0) / n_samples
#      37 term1_sum = np.sum(term1)
#
# File <__array_function__ internals>:5, in sum(*args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/numpy/core/fromnumeric.py:2259, in sum(a, axis, dtype, out, keepdims, initial, where)
#    2256         return out
#    2257     return res
# -> 2259 return _wrapreduction(a, np.add, 'sum', axis, dtype, out, keepdims=keepdims,
#    2260                       initial=initial, where=where)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/numpy/core/fromnumeric.py:86, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      83         else:
#      84             return reduction(axis=axis, out=out, **passkwargs)
# ---> 86 return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# KeyboardInterrupt:

# %%
power_new = {'0.9': 1, 
             '0.8': 1, 
             '0.7': 1, 
             '0.6': 1,
             '0.5': 1, 
             '0.4': 1,
             '0.3': 1, 
             '0.2': 1,
             '0.1': 1}

# %%
plot_test(list(power_new.values()), 'power')

# %% [markdown]
# ## case 3, no edges, gt_rejects = [0, 0, 0, 0]

# %%
power ={}
for d in tqdm(np.arange(1, 0.1, -0.1)):
    rejects = 0
    for i in tqdm(np.arange(100)):
        d1, d2, _, d3 = nonstationary_ts_n(n_sample=300, t_time=10, d=0.5, mode='case3', a=d, order=3)
        kd1 = compute_kernel_n(d1)
        kd2 = compute_kernel_n(d2)
        kd3 = compute_kernel_n(d3)
        _, _, _, reject = test_independence([kd1, kd2, kd3],None,
                                                  mode = 'iid', n_perms=5000, alpha=0.05)
        rejects = rejects + reject
    power[str(d)] = rejects/100
    print(power)
print(power)
# Out:
#   0%|          | 0/9 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# {'1.0': 0.07}
#   0%|          | 0/100 [00:00<?, ?it/s]
# {'1.0': 0.07, '0.9': 0.02}
#   0%|          | 0/100 [00:00<?, ?it/s]
# {'1.0': 0.07, '0.9': 0.02, '0.8': 0.05}
#   0%|          | 0/100 [00:00<?, ?it/s]
# {'1.0': 0.07, '0.9': 0.02, '0.8': 0.05, '0.7000000000000001': 0.03}
#   0%|          | 0/100 [00:00<?, ?it/s]
# {'1.0': 0.07, '0.9': 0.02, '0.8': 0.05, '0.7000000000000001': 0.03, '0.6000000000000001': 0.08}
#   0%|          | 0/100 [00:00<?, ?it/s]
# {'1.0': 0.07, '0.9': 0.02, '0.8': 0.05, '0.7000000000000001': 0.03, '0.6000000000000001': 0.08, '0.5000000000000001': 0.06}
#   0%|          | 0/100 [00:00<?, ?it/s]
# {'1.0': 0.07, '0.9': 0.02, '0.8': 0.05, '0.7000000000000001': 0.03, '0.6000000000000001': 0.08, '0.5000000000000001': 0.06, '0.40000000000000013': 0.06}
#   0%|          | 0/100 [00:00<?, ?it/s]
# {'1.0': 0.07, '0.9': 0.02, '0.8': 0.05, '0.7000000000000001': 0.03, '0.6000000000000001': 0.08, '0.5000000000000001': 0.06, '0.40000000000000013': 0.06, '0.30000000000000016': 0.06}
#   0%|          | 0/100 [00:00<?, ?it/s]
# {'1.0': 0.07, '0.9': 0.02, '0.8': 0.05, '0.7000000000000001': 0.03, '0.6000000000000001': 0.08, '0.5000000000000001': 0.06, '0.40000000000000013': 0.06, '0.30000000000000016': 0.06, '0.20000000000000018': 0.02}
# {'1.0': 0.07, '0.9': 0.02, '0.8': 0.05, '0.7000000000000001': 0.03, '0.6000000000000001': 0.08, '0.5000000000000001': 0.06, '0.40000000000000013': 0.06, '0.30000000000000016': 0.06, '0.20000000000000018': 0.02}

# %%
power_new = {'0.9': 0.02, 
             '0.8': 0.05, 
             '0.7': 0.03, 
             '0.6': 0.08,
             '0.5': 0.06, 
             '0.4': 0.06,
             '0.3': 0.06, 
             '0.2': 0.02,
             '0.1': 0.02}

# %%
plot_test(list(power_new.values()), 'Type I error')

# %% [markdown]
# # tetrahedron

# %% [markdown]
# # case1 gt_reject = [1,0,0,0]
