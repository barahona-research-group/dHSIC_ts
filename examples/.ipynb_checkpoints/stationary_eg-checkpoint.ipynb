# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
sys.path.append('/Users/Tim/PycharmProjects/HOI/')

# %%
import pandas as pd
import numpy as np
from tqdm.notebook import tqdm
import matplotlib.pyplot as plt
import scipy

# %%
from synthetic_data import stationary_pb_ts, nonstationary_ts_n
from HOI.preprocessings import compute_kernel, compute_kernel_n
from HOI.tests import test_independence, dhsic_permutation, test_lancaster, estimate_tail_head

# %%
import matplotlib.pyplot as plt

# %%
rejects = 0
for i in tqdm(np.arange(100)):
    df = stationary_pb_ts(t_time = 100, d = 0.8, mode = "case1", a=0.5)
    data_dict, kernel_dict = compute_kernel(df)
    _, _, _, reject = test_independence([kernel_dict['d1'], kernel_dict['d2'], kernel_dict['d3']],
                             [data_dict['d1'], data_dict['d2'], data_dict['d3']],
                              n_perms=1000, alpha=0.05, mode = 'shifting')
    rejects = rejects + reject
print(rejects)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# 31

# %%
{'0.1': 0.01, 
 '0.2': 0.38, 
 '0.3': 0.64, 
 '0.4': 0.88, 
 '0.5': 0.96}

# %%
power ={}
for d in tqdm([0.9]):
    rejects = 0
    for i in tqdm(np.arange(100)):
        df = stationary_pb_ts(t_time = 100, d = d, mode = "case1", a=0.5)
        data_dict, kernel_dict = compute_kernel(df)
        _, _, _, reject = test_independence([kernel_dict['d1'], kernel_dict['d3']],
                                         [data_dict['d1'], data_dict['d3']],
                                          n_perms=1000, alpha=0.05, mode='shifting')
        rejects = rejects + reject
    print(rejects)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# 12

# %%
rejects
# Out:
# 0

# %%
# all pairwise independent but jointly dependent
power ={}
for d in tqdm(np.arange(0.1, 1, 0.1)):
    rejects = 0
    for i in tqdm(np.arange(100)):
        df = stationary_pb_ts(t_time = 300, d = d, mode = "case1", a=0.5)
        data_dict, kernel_dict = compute_kernel(df)
        _, _, _, reject = test_independence([kernel_dict['d1'], kernel_dict['d2'], kernel_dict['d3']],
                                         [data_dict['d1'], data_dict['d2'], data_dict['d3']],
                                          mode = 'stat_ts', n_perms=5000, alpha=0.05)
        rejects = rejects + reject
    power[str(d)] = rejects/100
print(power)
# Out:
#   0%|          | 0/9 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# {'0.1': 0.013333333333333334, '0.2': 0.02666666666666667, '0.30000000000000004': 0.06333333333333334, '0.4': 0.09, '0.5': 0.11333333333333333, '0.6': 0.22666666666666666, '0.7000000000000001': 0.23666666666666666, '0.8': 0.29333333333333333, '0.9': 0.31}

# %%
# new_values by right shifts
power_new = {'0.1': 0.03, 
         '0.2': 0.08, 
         '0.30000000000000004': 0.19, 
         '0.4': 0.27, 
         '0.5': 0.34, 
         '0.6': 0.68, 
         '0.7000000000000001': 0.71, 
         '0.8': 0.88, 
         '0.9': 0.93}

# %%
plot_test(list(power_new.values()), 'power')

# %%
# power1 = {'0.1': 0.34,
#  '0.2': 0.31,
#  '0.30000000000000004': 0.47,
#  '0.4': 0.49,
#  '0.5': 0.62,
#  '0.6': 0.71,
#  '0.7000000000000001': 0.72,
#  '0.8': 0.79,
#  '0.9': 0.87}

# %%
plot_test(list(power1.values()), 'power')

# %%
# 100% better than 3-way HSIC, comparable with lancaster test from paulr

# %% [markdown]
# # case2

# %%
power ={}
for d in tqdm(np.arange(0.09, 0, -0.01)):
    rejects = 0
    for i in tqdm(np.arange(100)):
        df = stationary_pb_ts(t_time = 1200, d = d, mode = "case2", a=0.5)
        data_dict, kernel_dict = compute_kernel(df)
        _, _, _, reject = test_independence([kernel_dict['d1'], kernel_dict['d2'], kernel_dict['d3']],
                                 [data_dict['d1'], data_dict['d2'], data_dict['d3']],
                                 n_perms=1000, alpha=0.05, mode = 'shifting')
        rejects = rejects + reject
    power[str(d)] = rejects/100
    print(power)
# Out:
#   0%|          | 0/9 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# {'0.09': 0.84}
#   0%|          | 0/100 [00:00<?, ?it/s]
# {'0.09': 0.84, '0.08': 0.72}
#   0%|          | 0/100 [00:00<?, ?it/s]
# {'0.09': 0.84, '0.08': 0.72, '0.07': 0.74}
#   0%|          | 0/100 [00:00<?, ?it/s]
# {'0.09': 0.84, '0.08': 0.72, '0.07': 0.74, '0.06000000000000001': 0.43}
#   0%|          | 0/100 [00:00<?, ?it/s]
# {'0.09': 0.84, '0.08': 0.72, '0.07': 0.74, '0.06000000000000001': 0.43, '0.05000000000000002': 0.34}
#   0%|          | 0/100 [00:00<?, ?it/s]
# {'0.09': 0.84, '0.08': 0.72, '0.07': 0.74, '0.06000000000000001': 0.43, '0.05000000000000002': 0.34, '0.04000000000000002': 0.26}
#   0%|          | 0/100 [00:00<?, ?it/s]
# {'0.09': 0.84, '0.08': 0.72, '0.07': 0.74, '0.06000000000000001': 0.43, '0.05000000000000002': 0.34, '0.04000000000000002': 0.26, '0.030000000000000027': 0.14}
#   0%|          | 0/100 [00:00<?, ?it/s]
# {'0.09': 0.84, '0.08': 0.72, '0.07': 0.74, '0.06000000000000001': 0.43, '0.05000000000000002': 0.34, '0.04000000000000002': 0.26, '0.030000000000000027': 0.14, '0.02000000000000003': 0.12}
#   0%|          | 0/100 [00:00<?, ?it/s]
# {'0.09': 0.84, '0.08': 0.72, '0.07': 0.74, '0.06000000000000001': 0.43, '0.05000000000000002': 0.34, '0.04000000000000002': 0.26, '0.030000000000000027': 0.14, '0.02000000000000003': 0.12, '0.010000000000000037': 0.07}

# %%
# all independent
power ={}
for d in tqdm(np.arange(0.1, 1, 0.1)):
    rejects = 0
    for i in tqdm(np.arange(100)):
        df = stationary_pb_ts(t_time = 300, d = 0, mode = "case3", a=d)
        data_dict, kernel_dict = compute_kernel(df)
        _, _, _, reject_1 = test_independence([kernel_dict['d1'], kernel_dict['d2'], kernel_dict['d3']],
                                         [data_dict['d1'], data_dict['d2'], data_dict['d3']],
                                          mode = 'stat_ts', n_perms=5000, alpha=0.05)
        _, _, _, reject_2 = test_independence([kernel_dict['d1'], kernel_dict['d3']],
                                         [data_dict['d1'], data_dict['d3']],
                                          mode = 'stat_ts', n_perms=5000, alpha=0.05)
        
        rejects = rejects + reject_1 + reject_2 * 3
    power[str(d)] = rejects/400
    print(power)
# Out:
#   0%|          | 0/9 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# {'0.1': 0.05}
#   0%|          | 0/100 [00:00<?, ?it/s]
# {'0.1': 0.05, '0.2': 0.0425}
#   0%|          | 0/100 [00:00<?, ?it/s]
# {'0.1': 0.05, '0.2': 0.0425, '0.30000000000000004': 0.065}
#   0%|          | 0/100 [00:00<?, ?it/s]
# {'0.1': 0.05, '0.2': 0.0425, '0.30000000000000004': 0.065, '0.4': 0.045}
#   0%|          | 0/100 [00:00<?, ?it/s]
# {'0.1': 0.05, '0.2': 0.0425, '0.30000000000000004': 0.065, '0.4': 0.045, '0.5': 0.0675}
#   0%|          | 0/100 [00:00<?, ?it/s]
# {'0.1': 0.05, '0.2': 0.0425, '0.30000000000000004': 0.065, '0.4': 0.045, '0.5': 0.0675, '0.6': 0.065}
#   0%|          | 0/100 [00:00<?, ?it/s]
# {'0.1': 0.05, '0.2': 0.0425, '0.30000000000000004': 0.065, '0.4': 0.045, '0.5': 0.0675, '0.6': 0.065, '0.7000000000000001': 0.09}
#   0%|          | 0/100 [00:00<?, ?it/s]
# {'0.1': 0.05, '0.2': 0.0425, '0.30000000000000004': 0.065, '0.4': 0.045, '0.5': 0.0675, '0.6': 0.065, '0.7000000000000001': 0.09, '0.8': 0.0475}
#   0%|          | 0/100 [00:00<?, ?it/s]
# {'0.1': 0.05, '0.2': 0.0425, '0.30000000000000004': 0.065, '0.4': 0.045, '0.5': 0.0675, '0.6': 0.065, '0.7000000000000001': 0.09, '0.8': 0.0475, '0.9': 0.08}

# %%
# better than last time
power_new = {'0.1': 0.05, 
         '0.2': 0.04, 
         '0.3': 0.06, 
         '0.4': 0.04, 
         '0.5': 0.07, 
         '0.6': 0.06, 
         '0.7': 0.09, 
         '0.8': 0.05, 
         '0.9': 0.08}

# %%
plot_test(list(power_new.values()), 'Type I error')

# %%
power3 = [0.17  , 0.17, 0.15  , 0.13  , 0.23  , 0.22, 0.21  , 0.23, 0.31  ]

# %%
plot_test(power3, 'Type I error')

# %%
d1, d2, d3 = stationary_pb_ts_n(n_sample = 300, t_time = 30, d = 0.9, mode = "case1", a=0.5)

# %%
rejects = 0
for i in tqdm(np.arange(100)):
    d1, d2, d3 = stationary_pb_ts_n(n_sample = 100, t_time = 10, d = 0.2, mode = "case1", a=0.5)
    k1 = compute_kernel_n(d1)
    k2 = compute_kernel_n(d2)
    k3 = compute_kernel_n(d3)
    _, _, _, reject_1 = test_independence([k1,k2,k3], None, mode = 'iid', n_perms=5000, alpha=0.05)

    rejects = rejects + reject_1
    
print(rejects)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# 42

# %%
k1 = compute_kernel_n(d1)
k2 = compute_kernel_n(d2)
k3 = compute_kernel_n(d3)

# %%
_, _, _, reject_1 = test_independence([k1,k2,k3], None, mode = 'iid', n_perms=5000, alpha=0.05)
_, _, _, reject_2 = test_independence([k1,k2], None, mode = 'iid', n_perms=5000, alpha=0.05)

# %%
reject_1, reject_2
# Out:
# (0, 0)

# %%
power ={}
for d in tqdm(np.arange(0.7, 1, 0.1)):
    rejects = 0
    for i in tqdm(np.arange(200)):
        d1, d2, d3 = stationary_pb_ts_n(n_sample = 300, t_time = 30, d = d, mode = "case1", a=0.5)
        k1 = compute_kernel_n(d1)
        k2 = compute_kernel_n(d2)
        k3 = compute_kernel_n(d3)
        _, _, _, reject_1 = test_independence([k1,k2,k3], None, mode = 'iid', n_perms=2000, alpha=0.05)
        
        rejects = rejects + reject_1
    power[str(d)] = rejects/200
    print(power)

print(power)
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
# {'0.7': 0.145}
#   0%|          | 0/200 [00:00<?, ?it/s]
# {'0.7': 0.145, '0.7999999999999999': 0.13}
#   0%|          | 0/200 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [9], in <cell line: 2>()
#       7     k2 = compute_kernel_n(d2)
#       8     k3 = compute_kernel_n(d3)
# ----> 9     _, _, _, reject_1 = test_independence([k1,k2,k3], None, mode = 'iid', n_perms=2000, alpha=0.05)
#      11     rejects = rejects + reject_1
#      12 power[str(d)] = rejects/200
#
# File /Users/Tim/PycharmProjects/HOI/HOI/tests.py:164, in test_independence(k_list, data_list, mode, n_perms, alpha)
#     162 if mode == 'iid':
#     163     statistic = compute_dHSIC_statistics(k_list)
# --> 164     critical_value, pval = permutation(k_list, n_samples, n_variables, statistic, n_perms, alpha)
#     165     reject = int(statistic > critical_value)
#     166     return statistic, critical_value, pval, reject
#
# File /Users/Tim/PycharmProjects/HOI/HOI/tests.py:29, in permutation(k_list, n_samples, n_variables, stat_found, n_perms, alpha)
#      27     term1 = term1 * k_perm
#      28     term2 = term2 * np.sum(k_perm) / (n_samples ** 2)
# ---> 29     term3 = term3 * np.sum(k_perm, axis=0) / n_samples
#      31 term1_sum = np.sum(term1)
#      32 term3_sum = np.sum(term3)
#
# KeyboardInterrupt:

# %%
df = pd.read_csv ('dependence_phases.csv',header=None)

# %%
d1 = np.array(df.iloc[0])
d2 = np.array(df.iloc[1])
d3 = np.array(df.iloc[2])
d4 = np.array(df.iloc[3])

df = pd.DataFrame(list(zip(d1[:1000], d2[:1000], d3[:1000], d4[:1000])), columns=['d1', 'd2', 'd3', 'd4'])

# %%
from statsmodels.tsa.stattools import adfuller
values = df['d4']
res = adfuller(values)
print('Augmneted Dickey_fuller Statistic: %f' % res[0])
print('p-value: %f' % res[1])
# Out:
# Augmneted Dickey_fuller Statistic: -7.134084
# p-value: 0.000000

# %%
data_dict, kernel_dict = compute_kernel(df)

# %%
power_set_k = find_comb([kernel_dict['d1'], kernel_dict['d2'], kernel_dict['d3'], kernel_dict['d4']])

# %%
power_set_d = find_comb([data_dict['d1'], data_dict['d2'], data_dict['d3'], data_dict['d4']])

# %%
power_set_name = find_comb(['d1', 'd2', 'd3', 'd4'])

# %%
power = {}
for (name, klist, dlist) in tqdm(zip(power_set_name, power_set_k, power_set_d), total=len(power_set_k)):
    rejects = 0
    for i in tqdm(range(10)):
        _, _, _, reject = test_independence(klist, dlist, n_perms=500, alpha=0.05, mode = 'shifting')
        rejects = rejects + reject
    power[str(name)] = rejects
    print(power)
# Out:
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
# {"['d1', 'd2']": 0}
#   0%|          | 0/10 [00:00<?, ?it/s]
# {"['d1', 'd2']": 0, "['d1', 'd3']": 0}
#   0%|          | 0/10 [00:00<?, ?it/s]
# {"['d1', 'd2']": 0, "['d1', 'd3']": 0, "['d1', 'd4']": 0}
#   0%|          | 0/10 [00:00<?, ?it/s]
# {"['d1', 'd2']": 0, "['d1', 'd3']": 0, "['d1', 'd4']": 0, "['d2', 'd3']": 0}
#   0%|          | 0/10 [00:00<?, ?it/s]
# {"['d1', 'd2']": 0, "['d1', 'd3']": 0, "['d1', 'd4']": 0, "['d2', 'd3']": 0, "['d2', 'd4']": 0}
#   0%|          | 0/10 [00:00<?, ?it/s]
# {"['d1', 'd2']": 0, "['d1', 'd3']": 0, "['d1', 'd4']": 0, "['d2', 'd3']": 0, "['d2', 'd4']": 0, "['d3', 'd4']": 0}
#   0%|          | 0/10 [00:00<?, ?it/s]
# {"['d1', 'd2']": 0, "['d1', 'd3']": 0, "['d1', 'd4']": 0, "['d2', 'd3']": 0, "['d2', 'd4']": 0, "['d3', 'd4']": 0, "['d1', 'd2', 'd3']": 10}
#   0%|          | 0/10 [00:00<?, ?it/s]
# {"['d1', 'd2']": 0, "['d1', 'd3']": 0, "['d1', 'd4']": 0, "['d2', 'd3']": 0, "['d2', 'd4']": 0, "['d3', 'd4']": 0, "['d1', 'd2', 'd3']": 10, "['d1', 'd2', 'd4']": 10}
#   0%|          | 0/10 [00:00<?, ?it/s]
# {"['d1', 'd2']": 0, "['d1', 'd3']": 0, "['d1', 'd4']": 0, "['d2', 'd3']": 0, "['d2', 'd4']": 0, "['d3', 'd4']": 0, "['d1', 'd2', 'd3']": 10, "['d1', 'd2', 'd4']": 10, "['d1', 'd3', 'd4']": 10}
#   0%|          | 0/10 [00:00<?, ?it/s]
# {"['d1', 'd2']": 0, "['d1', 'd3']": 0, "['d1', 'd4']": 0, "['d2', 'd3']": 0, "['d2', 'd4']": 0, "['d3', 'd4']": 0, "['d1', 'd2', 'd3']": 10, "['d1', 'd2', 'd4']": 10, "['d1', 'd3', 'd4']": 10, "['d2', 'd3', 'd4']": 10}
#   0%|          | 0/10 [00:00<?, ?it/s]
# {"['d1', 'd2']": 0, "['d1', 'd3']": 0, "['d1', 'd4']": 0, "['d2', 'd3']": 0, "['d2', 'd4']": 0, "['d3', 'd4']": 0, "['d1', 'd2', 'd3']": 10, "['d1', 'd2', 'd4']": 10, "['d1', 'd3', 'd4']": 10, "['d2', 'd3', 'd4']": 10, "['d1', 'd2', 'd3', 'd4']": 10}

# %%
mat = scipy.io.loadmat('multiple_samples_dependence.mat')

# %%
mat['all_samples'].shape
# Out:
# (80, 4, 3000)

# %%
md1 = mat['all_samples'][:,0,:][:,0:100]
md2 = mat['all_samples'][:,1,:][:,0:100]
md3 = mat['all_samples'][:,2,:][:,0:100]
md4 = mat['all_samples'][:,3,:][:,0:100]

kmd1 = compute_kernel_n(md1)
kmd2 = compute_kernel_n(md2)
kmd3 = compute_kernel_n(md3)
kmd4 = compute_kernel_n(md4)

# %%
md1.shape, kmd1.shape
# Out:
# ((80, 100), (80, 80))

# %%
power_set = find_comb([kmd1, kmd2, kmd3, kmd4])

# %%
power_set_name = find_comb(['d1', 'd2', 'd3', 'd4'])

# %%
power = {}
for (name, klist) in tqdm(zip(power_set_name, power_set), total=len(power_set)):
    rejects = 0
    for i in tqdm(range(10)):
        _, _, _, reject = test_independence(klist, None, n_perms=1000, alpha=0.05, mode = 'permutation')
        rejects = rejects + reject
    power[str(name)] = rejects
    print(power)
# Out:
#   0%|          | 0/11 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
# {"['d1', 'd2']": 0}
#   0%|          | 0/10 [00:00<?, ?it/s]
# {"['d1', 'd2']": 0, "['d1', 'd3']": 10}
#   0%|          | 0/10 [00:00<?, ?it/s]
# {"['d1', 'd2']": 0, "['d1', 'd3']": 10, "['d1', 'd4']": 10}
#   0%|          | 0/10 [00:00<?, ?it/s]
# {"['d1', 'd2']": 0, "['d1', 'd3']": 10, "['d1', 'd4']": 10, "['d2', 'd3']": 10}
#   0%|          | 0/10 [00:00<?, ?it/s]
# {"['d1', 'd2']": 0, "['d1', 'd3']": 10, "['d1', 'd4']": 10, "['d2', 'd3']": 10, "['d2', 'd4']": 10}
#   0%|          | 0/10 [00:00<?, ?it/s]
# {"['d1', 'd2']": 0, "['d1', 'd3']": 10, "['d1', 'd4']": 10, "['d2', 'd3']": 10, "['d2', 'd4']": 10, "['d3', 'd4']": 0}
#   0%|          | 0/10 [00:00<?, ?it/s]
# {"['d1', 'd2']": 0, "['d1', 'd3']": 10, "['d1', 'd4']": 10, "['d2', 'd3']": 10, "['d2', 'd4']": 10, "['d3', 'd4']": 0, "['d1', 'd2', 'd3']": 10}
#   0%|          | 0/10 [00:00<?, ?it/s]
# {"['d1', 'd2']": 0, "['d1', 'd3']": 10, "['d1', 'd4']": 10, "['d2', 'd3']": 10, "['d2', 'd4']": 10, "['d3', 'd4']": 0, "['d1', 'd2', 'd3']": 10, "['d1', 'd2', 'd4']": 10}
#   0%|          | 0/10 [00:00<?, ?it/s]
# {"['d1', 'd2']": 0, "['d1', 'd3']": 10, "['d1', 'd4']": 10, "['d2', 'd3']": 10, "['d2', 'd4']": 10, "['d3', 'd4']": 0, "['d1', 'd2', 'd3']": 10, "['d1', 'd2', 'd4']": 10, "['d1', 'd3', 'd4']": 10}
#   0%|          | 0/10 [00:00<?, ?it/s]
# {"['d1', 'd2']": 0, "['d1', 'd3']": 10, "['d1', 'd4']": 10, "['d2', 'd3']": 10, "['d2', 'd4']": 10, "['d3', 'd4']": 0, "['d1', 'd2', 'd3']": 10, "['d1', 'd2', 'd4']": 10, "['d1', 'd3', 'd4']": 10, "['d2', 'd3', 'd4']": 10}
#   0%|          | 0/10 [00:00<?, ?it/s]
# {"['d1', 'd2']": 0, "['d1', 'd3']": 10, "['d1', 'd4']": 10, "['d2', 'd3']": 10, "['d2', 'd4']": 10, "['d3', 'd4']": 0, "['d1', 'd2', 'd3']": 10, "['d1', 'd2', 'd4']": 10, "['d1', 'd3', 'd4']": 10, "['d2', 'd3', 'd4']": 10, "['d1', 'd2', 'd3', 'd4']": 10}

# %%
power
# Out:
# {}

# %%
cor_n = []
cor_s = []
for s in tqdm(np.arange(0.1, 1, 0.05)):
    df = stationary_pb_ts(t_time = 300, d = s, mode = "case1", a=0.5)
    _, kernel_dict = compute_kernel(df)
    k_list = list(kernel_dict.values())
    cor_n.append(dHcor2_norm(k_list))
    cor_s.append(dHcor2_std(k_list))
# Out:
#   0%|          | 0/18 [00:00<?, ?it/s]

# %%
cor_n = [ round(elem, 3) for elem in cor_n ]
cor_s = [ round(elem, 3) for elem in cor_s ]

# %%
np.array(cor_s)/ np.array(cor_n)
# Out:
# array([6.05882353, 6.        , 5.85      , 5.76923077, 5.8       ,
#        5.86666667, 5.86666667, 5.92307692, 5.75      , 5.95652174,
#        6.04545455, 5.91666667, 5.95652174, 5.93103448, 5.95238095,
#        5.95454545, 5.78125   , 5.975     ])

# %%
plot_cor(cor_n, 'norm')

# %%
plot_cor(cor_s, 'std')

# %%
cor_n = []
cor_s = []
for s in tqdm(np.arange(0.1, 1, 0.05)):
    df = stationary_pb_ts(t_time = 300, d = s, mode = "case2", a=0.5)
    _, kernel_dict = compute_kernel(df)
    k_list = list(kernel_dict.values())
    cor_n.append(dHcor2_norm(k_list))
    cor_s.append(dHcor2_std(k_list))
# Out:
#   0%|          | 0/18 [00:00<?, ?it/s]

# %%
cor_n = [ round(elem, 3) for elem in cor_n ]
cor_s = [ round(elem, 3) for elem in cor_s ]

# %%
np.array(cor_s)/ np.array(cor_n)
# Out:
# array([5.77777778, 5.84210526, 6.15      , 5.8372093 , 5.81818182,
#        5.75757576, 6.        , 5.94117647, 6.09876543, 6.00746269,
#        5.76851852, 5.90666667, 5.88125   , 6.07894737, 6.02424242,
#        5.93236715, 5.95522388, 6.07142857])

# %%
plot_cor(cor_n, 'norm')

# %%
plot_cor(cor_s, 'std')

# %%
np.array(cor_s)/ np.array(cor_n)
# Out:
# array([5.77777778, 5.84210526, 6.15      , 5.8372093 , 5.81818182,
#        5.75757576, 6.        , 5.94117647, 6.09876543, 6.00746269,
#        5.76851852, 5.90666667, 5.88125   , 6.07894737, 6.02424242,
#        5.93236715, 5.95522388, 6.07142857])
